# %%
import numpy as np
from keras.models import load_model
from keras.models import model_from_json
from keras.preprocessing import image

# %% [markdown]
# # Accuracy data set load

# %% [markdown]
# 'dataset/Accuracy_test/dogs'에 개의 사진을 넣고, 'dataset/Accuracy_test/cats'에 고양이의 사진을 넣고 아래 코드를 실행

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/Accuracy_test',
                                            target_size = (64,64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 20 images belonging to 2 classes.

# %% [markdown]
# 아래 코드를 실행하고 클래스가 cats와 dogs로 나타나는지 확인한다. 이 외의 클래스가 존재한다면 'dataset/Accuracy_test'에 해당 폴더를 삭제한다.

# %%
# Out:
# (array([[[[0.34117648, 0.49803925, 0.2509804 ],
#           [0.46274513, 0.6117647 , 0.3803922 ],
#           [0.4666667 , 0.60784316, 0.35686275],
#           ...,
#           [0.33333334, 0.49411768, 0.21960786],
#           [0.37254903, 0.5254902 , 0.2784314 ],
#           [0.3372549 , 0.48235297, 0.27058825]],
#
#          [[0.43529415, 0.5882353 , 0.33333334],
#           [0.3529412 , 0.5058824 , 0.25882354],
#           [0.43137258, 0.59607846, 0.3137255 ],
#           ...,
#           [0.40000004, 0.54509807, 0.28235295],
#           [0.29411766, 0.43529415, 0.19215688],
#           [0.30588236, 0.4431373 , 0.22352943]],
#
#          [[0.4784314 , 0.6156863 , 0.4039216 ],
#           [0.427451  , 0.5764706 , 0.3529412 ],
#           [0.4156863 , 0.5686275 , 0.32156864],
#           ...,
#           [0.37647063, 0.5294118 , 0.26666668],
#           [0.45098042, 0.57254905, 0.3372549 ],
#           [0.47058827, 0.5921569 , 0.36862746]],
#
#          ...,
#
# ...

# %% [markdown]
# # Cat and Dog Classifier model load

# %%
model = load_model('CatandDogClassifier.h5')

# %%
model.evaluate(test_set)
# Out:
#     913/Unknown - 184s 201ms/step - loss: 3.7000 - accuracy: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f119a358fdff> in <module>
# ----> 1 model.evaluate(test_set)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1079                 step_num=step):
# ...
